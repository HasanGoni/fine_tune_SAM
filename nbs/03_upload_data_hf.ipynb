# %% [markdown]
# # Hugging Face data download is here

# %% [markdown]
# > data is uploaded in huggingface format and here we can download it and visualize it

# %%
#| default_exp hf_dataset

# %%
#| export
from typing import List, Dict, Union, Optional
from datasets import load_dataset, Dataset
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['image.cmap'] = 'gray'

# %%
dataset = load_dataset("hasangoni/Electron_microscopy_dataset")
# Out:
# Found cached dataset parquet (/home/hasan/.cache/huggingface/datasets/hasangoni___parquet/hasangoni--Electron_microscopy_dataset-f1bcfa6489f74966/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#| export
def show_hf_dataset(
        dataset:Dataset,
        idx:Union[int, None]=None,
        split:str='train'
        ):
    "Show hugging face random index"

    if idx is None:
        idx = np.random.randint(0, len(dataset[split]))

    print(f' dataset index will be visualized: {idx}')
    im_ = dataset[split]['image'][idx]
    msk_ = dataset[split]['label'][idx]
    fig, ax = plt.subplots(
        1, 2, figsize=(10, 5)
    )
    ax[0].imshow(im_)
    ax[0].set_title('image')
    ax[0].axis('off')
    ax[1].imshow(msk_)
    ax[1].set_title('mask')
    ax[1].axis('off')

# %%
show_hf_dataset(dataset)
# Out:
#  dataset index will be visualized: 300

# %%
#| hide
import nbdev; nbdev.nbdev_export('03_upload_data_hf.ipynb')
